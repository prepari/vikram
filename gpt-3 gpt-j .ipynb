# %%
# OPENAI_API_KEY = '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'
import os 
os.environ['OPENAI_API_KEY'] = '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'
import pandas as pd

# %%
pip install --upgrade openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 2.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 0.26.5
#     Uninstalling openai-0.26.5:
#       Successfully uninstalled openai-0.26.5
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# input_prompt = '''

# Write a dialogue between 2 people. You will  be provided with some details about dialogue .Each speaker will be speaking equivalent to number of segement.For example in number of segement is 3 .
# It means the speaker 1 will speak 3 times and speaker 2 will speak 3 times.

# Details provide by user about the dialogue:

# 1.Speaker 1 : Prithu | English  Speaking|Hotel Manager 
# 2.Speaker 2 : Anand  | Hindi Speaking |Customer
# 3.Topic : Anand has made an online ticket booking for Hotel but he has not got any communication.
# 4.Total segment : 12

# Use text  format of below given example between  delimited by double quotes 

# "

# Details provide by user aboutthe dialogue:

# 1.Speaker 1 : Michelle | English  Speaking| NA 
# 2.Speaker 2 : Rohan  | Hindi Speaking |Customer
# 3.Topic : Rohan, who is having dental problems and need to undergo Root canal Treatment (RCT).
# 4.Total segment : 3

# Start : This is dialogue between between dentist Michelle and a Hindi speaking man Rohan, who is having dental problems and need to undergo Root canal Treatment (RCT).
# Hi, Rohan. How are you doing today?
# मैं ठीक हूँ, धन्यवाद। मैं बस अपने दंत नियुक्ति के बारे में थोड़ा सा घबरा रहा हूँ।
# I understand. It's perfectly normal to feel nervous before a dental visit.
# हाँ, मुझे पता है। लेकिन मेरे दांतों में कुछ दर्द हो रहा है, और मुझे चिंता है कि दंत चिकित्सक क्या कहने वाला है।
# Don't worry, I'm sure everything will be fine. We'll just take a look and see what's going on.
# रोहन: ठीक है, धन्यवाद। आपके आश्वासन की सराहना करता हूँ।
# "

# '''

# %%
input_prompt = '''

Write a dialogue between 2 people. You will  be provided with some details about dialogue .

Details about the dialogue:
Domain : Customr Care 
Gender of English speaker: Female
LOTE: Hindi
Gender of LOTE speaker: Female
Scenario : Anand has made an online ticket booking for Hotel but he has not got any communication.Please follow below instruction - 

- Write it like a conbverstation between 2 people . One person will be speaking in English while other person is speaking in specfiend LOTE . You can use format of below given coneversation  given between  delimited by double quotes.
- Number of item under Segments should be 12.
- Only return the Dialogue section given between curly brackets.

"
Details about the dialogue:
Domain : Education
Gender of English speaker: Female
LOTE: Hindi
Gender of LOTE speaker: Female
Scenario : This dialogue is an interview between a mother, and a school Principal, Ms Karen Black. The mother is seeking information on how to process her daughter’s enrolment at the school.


{
"Domain":"Education",
"Topic" : "School Enrollement",    
"Scenario" : "This dialogue is an interview between a mother, and a school Principal, Ms Karen Black. The mother is seeking information on how 
to process her daughter’s enrolment at the school.The dialogue begins now:",
"Speaker" :["ENGLISH","HINDI","ENGLISH","HINDI","ENGLISH","HINDI","ENGLISH","HINDI","ENGLISH","HINDI","ENGLISH","HINDI"],
"Segments" : ["Good afternoon. I am Karen Black, the Principal. Thank you for your interest in enrolling your daughter at our school.","शुभ दोपहर, सुश्री ब्लैक। इस साक्षात्कार के लिए आपका बहुत-बहुत धन्यवाद. 
हम कुछ महीने पहले ऑस्ट्रेलिया पहुंचे और मैं चाहता हूं कि मेरी बेटी जल्द से जल्द स्कूल जाना शुरू कर दे।","We can help you with the enrolment. Firstly, does your child have any health or medical conditions, such as allergies, that we need to be aware of?",
"नहीं, मेरी बेटी स्वस्थ है और उसे उसकी उम्र के अनुसार सभी टीके लग गए हैं। वह बहुत बुद्धिमान है और पहले से ही कुछ अंग्रेजी समझती है।","That is great! She will need to do a proficiency test in English to assess whether she may need language support.",
"वह अभी भी अच्छा नहीं लिख सकती. परीक्षण कैसा होगा? यदि वह अंग्रेजी में अच्छा प्रदर्शन नहीं करती तो क्या उसे स्वीकार नहीं किया जाएगा? वह अभी भी बहुत छोटी है!","Don’t worry. The test is suitable for her age. It will assess her understanding of English and basic literacy skills according to the year she will be enrolled in.",
"मैं यह भी जानना चाहूंगा कि उसके नामांकन के लिए कौन से दस्तावेज़ आवश्यक हैं। मैं नहीं चाहता कि उसकी कोई और कक्षा छूटे! मुझे डर है कि वह अपने सहपाठियों से पिछड़ जायेगी।","We need proof of residential address, such as a utility bill, as well as the child’s birth certificate and immunisation records. We will also need parents’ details, visa status and passport copies.",
"ठीक है। मैं उन दस्तावेज़ों को व्यवस्थित करने जा रहा हूं और मैं उन्हें इस सप्ताह के अंत में लाऊंगा। मुझे बहुत खुशी है कि वह इस सेमेस्टर में कक्षाएं शुरू कर सकती हैं।","Is there anything else that you would like to know? Please feel free to contact us if you think about anything else later.",
"नहीं, अभी के लिए बस इतना ही। बहुत बहुत धन्यवाद, सुश्री ब्लैक।"
]
}

'''

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {
            "role": "user",
            "content": input_prompt
        }
    ],
    temperature=0,
    max_tokens=2048
)
dialogue = response['choices'][0]['message']['content']

# %%
data = pd.read_json(dialogue)
df = pd.DataFrame(data)
print(df)
# Out:
#            Domain                 Topic  \
# 0   Customer Care  Online Hotel Booking
# 1   Customer Care  Online Hotel Booking
# 2   Customer Care  Online Hotel Booking
# 3   Customer Care  Online Hotel Booking
# 4   Customer Care  Online Hotel Booking
# 5   Customer Care  Online Hotel Booking
# 6   Customer Care  Online Hotel Booking
# 7   Customer Care  Online Hotel Booking
# 8   Customer Care  Online Hotel Booking
# 9   Customer Care  Online Hotel Booking
# 10  Customer Care  Online Hotel Booking
# 11  Customer Care  Online Hotel Booking
#
#                                              Scenario  Speaker  \
# 0   This dialogue is between a customer, Anand, an...  ENGLISH
# 1   This dialogue is between a customer, Anand, an...    HINDI
# 2   This dialogue is between a customer, Anand, an...  ENGLISH
# 3   This dialogue is between a customer, Anand, an...    HINDI
# 4   This dialogue is between a customer, Anand, an...  ENGLISH
# ...

# %%
for i  in range(12):
   print(df['Segments'][i])
# Out:
# Good day, Anand. I understand you have a concern about your hotel booking. Can you please provide me with your booking reference number?
# नमस्ते, मैंने अपने होटल की बुकिंग की थी लेकिन मुझे अभी तक कोई संवाद नहीं मिला है। मेरा बुकिंग संदर्भ संख्या 12345 है।
# Thank you for the information, Anand. Let me check the details for you.
# धन्यवाद, मैं इंतजार कर रहा हूं।
# I have checked your booking and it seems there was a delay in sending the confirmation email due to a technical glitch. I apologize for the inconvenience. I will resend the confirmation email right away.
# ठीक है, मैं उम्मीद करता हूं कि मैं जल्द ही ईमेल प्राप्त करूंगा। क्या आप मुझे बता सकते हैं कि मैंने जो होटल बुक किया है वह कैसा है?
# Certainly, Anand. The hotel you have booked is well-rated by our customers. It has excellent facilities and is located in a convenient location.
# धन्यवाद, मुझे उम्मीद है कि मेरा ठहरने का अनुभव अच्छा होगा। क्या आप मुझे बता सकते हैं कि मैं चेक-इन का समय कैसे बदल सकता हूं?
# ...

# %%
data = pd.read_json(dialogue)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#            Domain                 Topic  \
# 0   Customer Care  Online Hotel Booking
# 1   Customer Care  Online Hotel Booking
# 2   Customer Care  Online Hotel Booking
# 3   Customer Care  Online Hotel Booking
# 4   Customer Care  Online Hotel Booking
# 5   Customer Care  Online Hotel Booking
# 6   Customer Care  Online Hotel Booking
# 7   Customer Care  Online Hotel Booking
# 8   Customer Care  Online Hotel Booking
# 9   Customer Care  Online Hotel Booking
# 10  Customer Care  Online Hotel Booking
# 11  Customer Care  Online Hotel Booking
#
#                                              Scenario  Speaker  \
# 0   This dialogue is between a customer, Anand, an...  ENGLISH
# 1   This dialogue is between a customer, Anand, an...    HINDI
# 2   This dialogue is between a customer, Anand, an...  ENGLISH
# 3   This dialogue is between a customer, Anand, an...    HINDI
# 4   This dialogue is between a customer, Anand, an...  ENGLISH
# ...
